# %%
pip install pands
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pands (from versions: none)
# ERROR: No matching distribution found for pands

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy.stats import f_oneway
from statsmodels.formula.api import ols

# %%
df = pd.read_csv(r'C:\Users\d\Desktop\listings22.csv')

# %%
df
# Out:
#                                                     id  \
# 0    1489424,"Welcoming, easygoing, comfy bed, enti...
# 1                                              2992450
# 2                                              3820211
# 3                                              5651579
# 4                                              6623339
# ..                                                 ...
# 402                                1091422934956081673
# 403                                1091500387329731524
# 404                                1097995825442731795
# 405  1100876731732967826,"Homey, Quiet 2BR W/ Washe...
# 406  1104977057298366617,"Safe, Affordable, Adorabl...
#
#                                                  name      host_id host_name  \
# 0                                                 NaN          NaN       NaN
# 1                          Luxury 2 bedroom apartment    4621559.0   Kenneth
# ...

# %%
mean_price_by_room_type=df.groupby('room_type')['price'].mean()
#حساب متوسط الاسعار حسب نوع الغرفة

# %%
mean_price_by_room_type
# Out:
# room_type
# Entire home/apt    130.748792
# Private room        89.600000
# Shared room         75.000000
# Name: price, dtype: float64

# %%
df
# Out:
#                                                     id  \
# 0    1489424,"Welcoming, easygoing, comfy bed, enti...
# 1                                              2992450
# 2                                              3820211
# 3                                              5651579
# 4                                              6623339
# ..                                                 ...
# 402                                1091422934956081673
# 403                                1091500387329731524
# 404                                1097995825442731795
# 405  1100876731732967826,"Homey, Quiet 2BR W/ Washe...
# 406  1104977057298366617,"Safe, Affordable, Adorabl...
#
#                                                  name      host_id host_name  \
# 0                                                 NaN          NaN       NaN
# 1                          Luxury 2 bedroom apartment    4621559.0   Kenneth
# ...

# %%
df.iloc[2:,:]
# Out:
#                                                     id  \
# 2                                              3820211
# 3                                              5651579
# 4                                              6623339
# 5                                              7563949
# 6                                              8035768
# ..                                                 ...
# 402                                1091422934956081673
# 403                                1091500387329731524
# 404                                1097995825442731795
# 405  1100876731732967826,"Homey, Quiet 2BR W/ Washe...
# 406  1104977057298366617,"Safe, Affordable, Adorabl...
#
#                                                  name      host_id host_name  \
# 2           Restored Precinct in Center Sq. w/Parking   19648678.0     Terra
# 3          Large studio apt  by Capital Center & ESP@   29288920.0     Gregg
# ...

# %%
df = df.drop('id',axis=1)

# %%
df
# Out:
#                                                  name      host_id host_name  \
# 0                                                 NaN          NaN       NaN
# 1                          Luxury 2 bedroom apartment    4621559.0   Kenneth
# 2           Restored Precinct in Center Sq. w/Parking   19648678.0     Terra
# 3          Large studio apt  by Capital Center & ESP@   29288920.0     Gregg
# 4    Center Sq. Loft in Converted Precinct w/ Parking   19648678.0     Terra
# ..                                                ...          ...       ...
# 402                    2 bed with parking off Madison  232967878.0     Diana
# 403                  Triplex oasis w:parking near MVP  232967878.0     Diana
# 404                          New Center square studio  232967878.0     Diana
# 405                                               NaN          NaN       NaN
# 406                                               NaN          NaN       NaN
#
# ...

# %%
df['lines']=df ['latitude'] + df['longitude']

# %%
df
# Out:
#                                                  name      host_id host_name  \
# 0                                                 NaN          NaN       NaN
# 1                          Luxury 2 bedroom apartment    4621559.0   Kenneth
# 2           Restored Precinct in Center Sq. w/Parking   19648678.0     Terra
# 3          Large studio apt  by Capital Center & ESP@   29288920.0     Gregg
# 4    Center Sq. Loft in Converted Precinct w/ Parking   19648678.0     Terra
# ..                                                ...          ...       ...
# 402                    2 bed with parking off Madison  232967878.0     Diana
# 403                  Triplex oasis w:parking near MVP  232967878.0     Diana
# 404                          New Center square studio  232967878.0     Diana
# 405                                               NaN          NaN       NaN
# 406                                               NaN          NaN       NaN
#
# ...

# %%
pd.crosstab(df['name'],df['number_of_reviews_ltm'],margins =True)
# Out:
# number_of_reviews_ltm                               0.0  1.0  2.0  3.0  4.0  \
# name
# $55twin($30 foreign student)FreeBF Noa/c no smoke     0    0    0    0    0
# & Modern Luxury Cottage in Central ALB                0    0    0    0    0
# * 1 bed near Times Union center & Egg w/parking *     0    0    0    0    0
# * Adorable home w/parking near great restaurants *    0    0    0    0    0
# * Centrally located Eclectic vibe 2 bed w/parking     0    0    0    0    0
# ...                                                 ...  ...  ...  ...  ...
# ✨Historic Full Amenities 2BR Apt @Downtown Albany     0    0    0    0    0
# ⭐Cozy Garden Suite Full Amenities @Downtown Albany    0    0    0    0    0
# ⭐⭐Check it out! This apartmnt has a bunch of great    0    0    0    0    0
# 🍃Chic & Cozy Near Washington Park Garden Suite        0    1    0    0    0
# All                                                  63   27   23   13   18
#
# ...

# %%
sns.scatterplot(x='price',y='number_of_reviews', data=df)
#رسم بياني يوضح علاقة السعر وعدد التقييمات
# Out:
# <Axes: xlabel='price', ylabel='number_of_reviews'>

# %%
 features = ['latitude','longitude']

# %%
df[features].hist()
# Out:
# array([[<Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'longitude'}>]], dtype=object)

# %%
print('وجد علاقه طردية بين السعر وعدد التقييمات -الغرف ذات الاسعار المنخفظه تجذب عادة عددا اكبر من التقييمات')
